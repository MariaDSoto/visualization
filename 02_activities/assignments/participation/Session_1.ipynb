# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
font1 = {'family': 'sans-serif', 'color': 'blue','size':20}
font2 = {'family': 'monospace', 'color': 'green', 'size':14}

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
ax.set_title('Total growth over time', fontdict=font1)
ax.set_ylabel('Total growth', fontdict=font2)
ax.set_xlabel('Years since start', fontdict=font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig, ax = plt.subplots (figsize=(5, 3))
ax.scatter (x, y, marker='*', color = "indigo")
fig.show()
# Out:
# /var/folders/90/vkpn7t6j78l0p3d3dg7j0prw0000gn/T/ipykernel_88442/961858972.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots (figsize=(5, 3))
ax.scatter (x, 
y, 
marker='*', 
color = "indigo",
linestyle='--',
linewidth=2)
fig.show()
# Out:
# /var/folders/90/vkpn7t6j78l0p3d3dg7j0prw0000gn/T/ipykernel_88442/655524612.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)
fig.show()
# Out:
# /var/folders/90/vkpn7t6j78l0p3d3dg7j0prw0000gn/T/ipykernel_88442/430778414.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig,ax = plt.subplots (figsize=(5, 3))
ax.plot(x,y,
marker='*', 
markersize=12,
color = "indigo",
linestyle='--',
linewidth=2,
markeredgecolor='#fa9359',
markerfacecolor='#000000')
fig.show()
# Out:
# /var/folders/90/vkpn7t6j78l0p3d3dg7j0prw0000gn/T/ipykernel_88442/1300238975.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig,ax = plt.subplots (figsize=(5, 3))
ax.plot(x,y,
marker='*', 
markersize=12,
color = "indigo",
linestyle='--',
linewidth=2,
markeredgecolor='#fa9359',
markerfacecolor='#000000')
ax.grid(axis = 'y')

# %%
fig,ax = plt.subplots (figsize=(5, 3))
ax.plot(x,y,
marker='*', 
markersize=12,
color = "indigo",
linestyle='--',
linewidth=2,
markeredgecolor='#fa9359',
markerfacecolor='#000000')
ax.grid(axis = 'y', color = "blue", linewidth = 2, linestyle = '-.')

# %% [markdown]
# I don't really have any comments except that I struggled to understand how to add the ax.grid function but I eventually understood how to apply it.

# %% [markdown]
# # Activity
# https://python-graph-gallery.com/4-add-title-and-axis-label/

# %%
# Replicating the figure
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# create dataset
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
x_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(x_pos, height, color = (0.5,0.1,0.5,0.6))
 
# Add title and axis names
plt.title('My Replication')
plt.xlabel('categories')
plt.ylabel('values')
 
# Create names on the x axis
plt.xticks(x_pos, bars)
 
# Show graph
plt.show()

# %% [markdown]
# # Aesthetic:
# I think the figure is simple yet visually appealing
# # Subtantive:
# Yes, the figure completely captures the values for each of the categories, therefore, I conclude that the visualization accurately represents the data.
# # Perceptual:
# If the goal is to compare the values for each of the categories then yes, the figure makes it easy to compare the different values for each of the categories.
